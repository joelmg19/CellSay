# %%
import os
import glob
from google.colab import files
from google.colab import drive
from IPython.display import Image, display

# 1. Instala Ultralytics (necesario después de reiniciar el entorno)
print("Instalando Ultralytics...")
# !pip install ultralytics

# 2. Montar Google Drive (de tu "cuenta nueva")
print("\nConectando Google Drive...")
try:
    drive.mount('/content/drive', force_remount=True)
    print("Google Drive montado exitosamente.")
except Exception as e:
    print(f"Error al montar Google Drive: {e}")

# 3. Define la ruta a tu MEJOR modelo
# (Asegúrate que esta ruta sea correcta en tu "cuenta nueva")
ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'

# 4. Pide subir un archivo (¡Aquí aparece el botón!)
print("\nPor favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 5. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 6. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 7. ¡Muestra la imagen con las detecciones! (Versión corregida)
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Instalando Ultralytics...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00
# ...
#
# Conectando Google Drive...
# Mounted at /content/drive
# Google Drive montado exitosamente.
#
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-36d4758d-f4f4-4df8-9ecb-035564689b0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36d4758d-f4f4-4df8-9ecb-035564689b0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-fb925117-f147-4e78-ab19-b7dc0351afe1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb925117-f147-4e78-ab19-b7dc0351afe1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-9b2cbafa-a8eb-412e-806a-c3db0f9961f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b2cbafa-a8eb-412e-806a-c3db0f9961f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-63eee06f-1eba-4978-8c41-e9a61a587a16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63eee06f-1eba-4978-8c41-e9a61a587a16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-290ae98b-4f9f-4362-86f8-733bb126017b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-290ae98b-4f9f-4362-86f8-733bb126017b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-ad74cbae-889b-4b7e-913e-2f3ad14bfbbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad74cbae-889b-4b7e-913e-2f3ad14bfbbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import os
import glob
from google.colab import files
from IPython.display import Image, display

# --- (Asegúrate de que la variable 'ruta_al_modelo' aún exista en la memoria) ---
# Si no existe, descomenta y ejecuta la línea de abajo primero:
# ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'


# 1. Pide subir un archivo (¡Aquí aparece el botón!)
print("Por favor, sube tu imagen de prueba:")
uploaded = files.upload()

# 2. Obtiene el nombre del archivo que acabas de subir
if list(uploaded.keys()):
    file_name = list(uploaded.keys())[0]
    print(f"\nArchivo '{file_name}' subido exitosamente.")

    # 3. Ejecuta la predicción sobre ESE archivo
    print("Ejecutando predicción (usando la GPU)...")
    # !yolo predict \
    model="{ruta_al_modelo}" \
    source="{file_name}" \
    save=True

    # 4. ¡Muestra la imagen con las detecciones!
    try:
        # Encuentra la carpeta de predicción MÁS RECIENTE
        list_of_dirs = glob.glob('/content/runs/detect/predict*')
        latest_dir = max(list_of_dirs, key=os.path.getctime)

        # Encuentra la imagen de resultado
        result_images = glob.glob(os.path.join(latest_dir, file_name.split('.')[0] + '.*'))

        if result_images:
            result_image_path = result_images[0]
            print(f"\n--- Resultado de la Predicción (desde {result_image_path}) ---")
            display(Image(filename=result_image_path))
        else:
            print(f"\nError: No se encontró el archivo de resultado '{file_name}' en la carpeta '{latest_dir}'.")

    except (ValueError, FileNotFoundError):
        print("\nError: No se pudo encontrar la imagen de resultado guardada.")
else:
    print("\nNo se subió ningún archivo.")
# Out:
# Por favor, sube tu imagen de prueba:
#      <input type="file" id="files-4a41b6ce-3f60-425b-b91c-874263694914" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a41b6ce-3f60-425b-b91c-874263694914">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Este comando nos dice si la GPU está activa
# !nvidia-smi
# Out:
# Tue Oct 21 03:42:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# 1. Instala Ultralytics (si no está ya)
# !pip install ultralytics

# 2. Monta tu Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# 3. Descarga el dataset (¡formato CORREGIDO!)
import os
from roboflow import Roboflow
print("Descargando dataset (necesario para la cuantización)...")
# (Usa tu clave API más reciente aquí)
rf = Roboflow(api_key="CjWCT39rcsdEwhXojlUj")
project = rf.workspace("mtrharry").project("proyecto_vision_urbana_unificado-9lysa")
version = project.version(2)
# --- CORRECCIÓN AQUÍ ---
dataset = version.download("yolov8") # <-- Volvemos a "yolov8"
data_yaml_path = os.path.join(dataset.location, 'data.yaml')
print(f"Dataset listo en: {data_yaml_path}")

# 4. Define la ruta al modelo
ruta_al_modelo = '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt'
print(f"Usando el modelo: {ruta_al_modelo}")

# 5. ¡EL COMANDO DE EXPORTACIÓN FORZANDO GPU!
print("\nIniciando exportación... (Forzando el uso de GPU con device=0)")
# !yolo export \
model="{ruta_al_modelo}" \
format=tflite \
int8=True \
imgsz=640 \
data="{data_yaml_path}" \
device=0   # <--- Forzar la GPU

print("\n¡Exportación completada!")

# 6. MUESTRA LOS ARCHIVOS RESULTANTES
print("\n--- Archivos en tu Google Drive ---")
# !ls -lh /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/
# Out:
# ...
# Mounted at /content/drive
# Descargando dataset (necesario para la cuantización)...
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset listo en: /content/Proyecto_Vision_Urbana_UNIFICADO-2/data.yaml
# Usando el modelo: /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt
#
# Iniciando exportación... (Forzando el uso de GPU con device=0)
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (11.8 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# --- CELDA DE EXPORTACIÓN (SIN INT8) ---

# (Asegúrate de que las variables 'ruta_al_modelo' y 'data_yaml_path' aún existan)
# Si no, vuelve a ejecutar las celdas anteriores para definirlas.

print("\nIniciando exportación a TFLite (FP32, sin INT8)...")
# !yolo export \
model="{ruta_al_modelo}" \
format=tflite \
imgsz=640 \
data="{data_yaml_path}" \
device=0

print("\n¡Exportación FP32 completada!")

# MUESTRA LOS ARCHIVOS RESULTANTES
print("\n--- Archivos en tu Google Drive ---")
# !ls -lh /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/
# Out:
# Iniciando exportación a TFLite (FP32, sin INT8)...
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (11.8 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761019157.801453   12529 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761019157.887003   12529 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Muestra el contenido de la carpeta donde SÍ está el TFLite
# !ls -lh /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best_saved_model/
# Out:
# total 0

# %%
# --- INTENTO #2: EXPORTACIÓN INT8 ---

# (Asegúrate de que 'ruta_al_modelo' y 'data_yaml_path' aún existan)

print("\nReintentando exportación y cuantización a TFLite (INT8)...")
# !yolo export \
model="{ruta_al_modelo}" \
format=tflite \
int8=True \
imgsz=640 \
data="{data_yaml_path}" \
device=0

print("\n¡Intento de exportación INT8 completado!")

# MUESTRA LOS ARCHIVOS RESULTANTES (AHORA BUSCANDO EN AMBOS LUGARES)
print("\n--- Archivos en tu Google Drive ---")
# !ls -lh /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/
print("\n--- Archivos dentro de best_saved_model ---")
# !ls -lh /content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best_saved_model/
# Out:
# Reintentando exportación y cuantización a TFLite (INT8)...
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,598 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Mi_Entrenamiento_YOLO/train_urbano_v2_10clases/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (11.8 MB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761018807.757130   11101 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761018807.763426   11101 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
